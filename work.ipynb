# %% [markdown]
# ##### 初次使用平台，您可请前往<a href="/public-project?tab=1" target="_blank">入门项目</a>了解项目使用规范和流程。
# ##### For the first time using the platform, you can go to the Entry Project to understand the project usage specifications and procedures.

# %% [markdown]
# ##### 当前挂载的数据集目录仅能查看，无法变更该目录下的内容。
# ##### The dataset directory can only be viewed. The contents of this directory cannot be changed.

# %%
# !ls /home/megstudio/dataset
# Out:
# dataset-2805  traffic5

# %% [markdown]
# ##### 查看工作区文件， 该目录下的变更将会持久保存。 您的所有项目将 **共享一个存储空间**，请及时清理不必要的文件，避免加载过慢。
# ##### View personal work directory. All changes under this directory will be kept even after reset.
# ##### All your projects will share one storage space, please clean unnecessary files in time to speed up environment loading.

# %%
# !ls /home/megstudio/workspace

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/train.py -n 4 -b 2 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805 -w weights/atss_res50_coco_3x_800size_42dot6_9a92ed8c.pkl
# Out:
# 21 07:54:44 Device Count = 4
# 21 07:54:49 load_serialized_obj_from_url: download to or using cached /home/megstudio/.cache/megengine/serialized/928d77_resnet50_fbaug_76254_4e14b7d1.pkl
# 21 07:54:49 load_serialized_obj_from_url: download to or using cached /home/megstudio/.cache/megengine/serialized/928d77_resnet50_fbaug_76254_4e14b7d1.pkl
# 21 07:54:49 load_serialized_obj_from_url: download to or using cached /home/megstudio/.cache/megengine/serialized/928d77_resnet50_fbaug_76254_4e14b7d1.pkl
# 21 07:54:49 load_serialized_obj_from_url: download to or using cached /home/megstudio/.cache/megengine/serialized/928d77_resnet50_fbaug_76254_4e14b7d1.pkl
# 21 07:54:50 ------------------------  ----------------------------------------------------------------------------------------------------------------------------------------------------------------------
# backbone                  resnet50
# backbone_pretrained       True
# backbone_norm             FrozenBN
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 4 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [00:44<00:00,  6.67it/s]
# 21 13:06:06 Save to logs/atss_res50_800size_trafficdet_demo_gpus4/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.31s).
# Accumulating evaluation results...
# DONE (t=0.42s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.774
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.621
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.638
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [04:43<00:00,  1.05it/s]
# 22 10:54:56 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.44s).
# Accumulating evaluation results...
# DONE (t=0.42s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.747
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.433
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.634
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:25<00:00,  1.46it/s]
# 22 10:59:07 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.42s).
# Accumulating evaluation results...
# DONE (t=0.40s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.761
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.645
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:10<00:00,  1.57it/s]
# 22 11:02:57 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.47s).
# Accumulating evaluation results...
# DONE (t=0.40s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.641
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:21<00:00,  1.48it/s]
# 22 13:19:37 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.26s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.31s).
# Accumulating evaluation results...
# DONE (t=0.39s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.766
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:47<00:00,  1.31it/s]
# 23 16:32:29 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.35s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.767
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.431
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.643
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:56<00:00,  1.26it/s]
# 23 16:37:43 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.37s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.647
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.641
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:56<00:00,  1.26it/s]
# 24 02:15:25 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.47s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.41s).
# Accumulating evaluation results...
# DONE (t=0.63s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.777
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.647
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.641
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:29<00:00,  1.43it/s]
# 25 13:26:09 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.49s).
# Accumulating evaluation results...
# DONE (t=0.41s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.774
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [03:25<00:00,  1.45it/s]
# 25 13:21:42 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.25s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.43s).
# Accumulating evaluation results...
# DONE (t=0.41s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.647
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.641
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# 100%|█████████████████████████████████████████| 299/299 [10:12<00:00,  2.05s/it]
# 25 13:44:35 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.40s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.774
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [05:48<00:00,  1.16s/it]
# 25 19:36:29 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.44s).
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [07:43<00:00,  1.55s/it]
# 25 19:45:23 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.45s).
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [11:30<00:00,  2.31s/it]
# 25 19:57:41 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.46s).
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [09:37<00:00,  1.93s/it]
# 25 20:07:49 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.44s).
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [12:54<00:00,  2.59s/it]
# 25 20:21:36 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.47s).
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.8, 0.9, 1.0, 1.1]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [11:18<00:00,  2.27s/it]
# 26 11:13:08 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.22s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.8, 0.85, 0.9, 0.95, 1.0, 1.05, 1.1]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [19:30<00:00,  3.91s/it]
# 26 11:55:29 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.8, 0.9, 1.0, 1.1, 1.2]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [15:26<00:00,  3.10s/it]
# 26 12:11:55 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.8, 0.9, 1.0, 1.1, 1.2]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [15:24<00:00,  3.09s/it]
# 26 12:28:56 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.49s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.75, 0.8, 0.9, 1.0, 1.1, 1.2]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [17:03<00:00,  3.42s/it]
# 26 12:47:13 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.6666, 0.75, 0.8, 0.9, 1.0, 1.1, 1.2]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [18:24<00:00,  3.69s/it]
# 26 13:38:55 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.24s)
# creating index...
# index created!
# Running per image evaluation...
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.75, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3]
#   0%|                                                   | 0/299 [00:00<?, ?it/s]tools/test.py:237: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 299/299 [22:03<00:00,  4.43s/it]
# 26 14:02:45 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/epoch_23.json finished, start evaluation!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.23s)
# creating index...
# index created!
# Running per image evaluation...
# ...

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.8, 0.9, 1.0, 1.1]
#   0%|                                                   | 0/584 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 584/584 [21:10<00:00,  2.18s/it]
# 26 11:34:32 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/test_final_epoch_23.json finished, start evaluation!

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.75, 0.8, 0.9, 1.0, 1.1, 1.2]
#   0%|                                                   | 0/584 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 584/584 [31:21<00:00,  3.22s/it]
# 26 13:20:11 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/test_final_epoch_23.json finished, start evaluation!

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset/dataset-2805
# Out:
# [0.75, 0.8, 0.9, 1.0, 1.1, 1.2, 1.3]
#   0%|                                                   | 0/584 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|█████████████████████████████████████████| 584/584 [40:32<00:00,  4.17s/it]
# 26 14:45:11 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/test_final_epoch_23.json finished, start evaluation!

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset
# Out:
# [0.8, 1.0]
#   0%|                                                 | 0/10066 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
#   7%|██▌                                  | 692/10066 [11:22<2:35:51,  1.00it/s]

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset
# Out:
# [1.0]
#   0%|                                                 | 0/10066 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
#   2%|▉                                    | 249/10066 [02:40<1:45:32,  1.55it/s]/bin/sh: line 1:   896 Killed                  python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset
# Out:
# [0.9]
#   0%|                                                 | 0/10066 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
# 100%|███████████████████████████████████| 10066/10066 [1:16:39<00:00,  2.19it/s]
# 27 06:27:26 Save to logs/atss_res50_800size_trafficdet_demo_gpus1/test_final_epoch_23.json finished, start evaluation!

# %%
# !export PYTHONPATH=~/workspace/megengine-trafficsign/trafficdet:$PYTHONPATH; cd ~/workspace/megengine-trafficsign/trafficdet; python3 tools/test_final.py -n 1 -se 23 -f configs/atss_res50_800size_trafficdet_demo.py -d ./dataset
# Out:
# [1.0]
#   0%|                                                 | 0/10066 [00:00<?, ?it/s]tools/test_final.py:205: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pred_res = np.array(dtboxes_all, dtype=np.float)
#   9%|███▏                                 | 865/10066 [16:21<2:53:35,  1.13s/it]
